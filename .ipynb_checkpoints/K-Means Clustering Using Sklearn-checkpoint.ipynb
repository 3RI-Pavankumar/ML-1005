# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import warnings
warnings.filterwarnings("ignore")

# %%
X, _ = make_blobs(n_samples=60, centers=[[2,1], [4,5], [7,2]])

# %%
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
sns.scatterplot(x=X[:,0], y=X[:,1], hue=_)
# Out:
# <Axes: >

# %%
model = KMeans(n_clusters=3)

# %%
model.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
model.cluster_centers_
# Out:
# array([[4.08161988, 4.73369417],
#        [7.01414723, 2.06606498],
#        [1.91603265, 1.13055751]])

# %%
y_pred = model.predict(X)

# %%
y_pred
# Out:
# array([2, 2, 1, 2, 1, 1, 2, 2, 1, 0, 0, 0, 2, 0, 0, 2, 1, 1, 1, 1, 0, 0,
#        1, 0, 2, 1, 0, 1, 1, 0, 0, 1, 2, 0, 1, 2, 2, 1, 1, 2, 0, 2, 0, 1,
#        0, 0, 2, 0, 0, 0, 2, 2, 2, 2, 0, 1, 1, 2, 0, 1])

# %%
sns.scatterplot(x=X[:,0], y=X[:,1], hue=y_pred)
# Out:
# <Axes: >

# %%
def calculate_wcss(data, k_range):
    wcss=[]
    for k in k_range:
        km = KMeans(n_clusters=k)
        km.fit(data)
        wcss.append(km.inertia_)
    return wcss

# %%
wcss = calculate_wcss(X, range(1, 9))

# %%
plt.plot(range(1, 9), wcss)
plt.scatter(range(1, 9), wcss, color="red")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.show()
